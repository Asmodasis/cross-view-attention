# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (3.6.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.19 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (1.23.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install -U scikit-learn
# !pip install -U scikit-image
# !pip install tqdm
# Out:
# Requirement already satisfied: scikit-learn in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (1.1.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from scikit-learn) (1.23.3)
# Collecting scikit-image
#   Using cached scikit_image-0.19.3-cp39-cp39-win_amd64.whl (12.1 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from scikit-image) (21.3)
# Collecting imageio>=2.4.1
#   Downloading imageio-2.22.4-py3-none-any.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.0 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from scikit-image) (1.23.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from scikit-image) (9.3.0)
# Collecting tifffile>=2019.7.26
#   Using cached tifffile-2022.10.10-py3-none-any.whl (210 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from scikit-image) (1.9.1)
# Collecting networkx>=2.2
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 4.4 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1
#   Using cached PyWavelets-1.4.1-cp39-cp39-win_amd64.whl (4.2 MB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from packaging>=20.0->scikit-image) (3.0.9)
# Installing collected packages: tifffile, PyWavelets, networkx, imageio, scikit-image
# Successfully installed PyWavelets-1.4.1 imageio-2.22.4 networkx-2.8.8 scikit-image-0.19.3 tifffile-2022.10.10
# Requirement already satisfied: tqdm in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (4.64.1)
# Requirement already satisfied: colorama in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tqdm) (0.4.5)

# %%
# !pip install keras_applications
# Out:
# Collecting keras_applications
#   Using cached Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
# Requirement already satisfied: h5py in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from keras_applications) (3.7.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\asmod\anaconda3\envs\tensorflow-gpu\lib\site-packages (from keras_applications) (1.23.3)
# Installing collected packages: keras_applications
# Successfully installed keras_applications-1.0.8

# %%
import matplotlib.pyplot as plt
import numpy as np
#import cv2
#import pandas as pd
import os
import numpy as np
#import numpy as np
import pandas as pd
import cv2
from PIL import Image
import scipy
import tensorflow as tf
from tensorflow.keras.applications import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.losses import *
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.preprocessing.image import *
from tensorflow.keras.utils import *
from sklearn.metrics import *
from sklearn.model_selection import *
import tensorflow.keras.backend as K
from tqdm import tqdm, tqdm_notebook
from colorama import Fore
import matplotlib.pyplot as plt
from glob import glob
from skimage.io import *
import time
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')
from keras.layers import Input
from keras import layers
from keras.layers import Dense
from keras.layers import Activation
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers import ZeroPadding2D
from keras.layers import AveragePooling2D
from keras.layers import GlobalAveragePooling2D
from keras.layers import BatchNormalization
from keras.layers import Softmax
from keras.models import Model
from keras.models import Sequential
from keras.preprocessing import image
import keras.backend as K
import keras_applications
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import decode_predictions
from keras.applications.imagenet_utils import preprocess_input
from keras_applications.imagenet_utils import _obtain_input_shape
from keras.utils.layer_utils import get_source_inputs
print("All modules have been imported")
# Out:
# All modules have been imported

# %%
scale_percent = 100 # percent of original size
width = int(np.round(600 * scale_percent / 100))
height = int(np.round(300 * scale_percent / 100))
dim = (width, height)

# %% [markdown]
# ###############################<br>
# # ResNet50 Model Definition ###<br>
# ###############################

# %%
WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels.h5'
WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5'

# %%
def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut.
    # Arguments
        input_tensor: input tensor
        kernel_size: defualt 3, the kernel size of middle conv layer at main path
        filters: list of integers, the filterss of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'..., current block label, used for generating layer names
    # Returns
        Output tensor for the block.
    """
    filters1, filters2, filters3 = filters
    if K.image_data_format() == 'channels_last':
        bn_axis = 3
    else:
        bn_axis = 1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    x = Conv2D(filters1, (1, 1), name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)
    x = Conv2D(filters2, kernel_size,
               padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)
    x = Conv2D(filters3, (1, 1), name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)
    x = layers.add([x, input_tensor])
    x = Activation('relu')(x)
    return x

# %%
def conv_block(input_tensor, kernel_size, filters, stage, block, strides=(2, 2)):
    """conv_block is the block that has a conv layer at shortcut
    # Arguments
        input_tensor: input tensor
        kernel_size: defualt 3, the kernel size of middle conv layer at main path
        filters: list of integers, the filterss of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'..., current block label, used for generating layer names
    # Returns
        Output tensor for the block.
    Note that from stage 3, the first conv layer at main path is with strides=(2,2)
    And the shortcut should have strides=(2,2) as well
    """
    filters1, filters2, filters3 = filters
    if K.image_data_format() == 'channels_last':
        bn_axis = 3
    else:
        bn_axis = 1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    x = Conv2D(filters1, (1, 1), strides=strides,
               name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)
    x = Conv2D(filters2, kernel_size, padding='same',
               name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)
    x = Conv2D(filters3, (1, 1), name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)
    shortcut = Conv2D(filters3, (1, 1), strides=strides,
                      name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)
    x = layers.add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
def cvam_block(x,x1,x2, ratio=8):
  """Contains the implementation of Convolutional Block Attention Module(CBAM) block.
  As described in https://arxiv.org/abs/1807.06521.
  """
  print('before',x)
  x_enhanced = channel_attention2(x,x2, ratio)
  print ('after',x_enhanced)
  cbam_feature = spatial_attention2(x_enhanced,x1)
  return cbam_feature
  #x=RMLO
  #x1=LMLO
  #x2=RCC
  #x3=LCC
def channel_attention2(x,x2, ratio=8):
  features=[x,x2]
  channel_axis = 1 if K.image_data_format() == "channels_first" else -1
  channel = x.shape[channel_axis]	
  #channel = input_feature.shape
  shared_layer_one = Dense(channel//ratio,
              activation='relu',
              kernel_initializer='he_normal',
              use_bias=True,
              bias_initializer='zeros')
  shared_layer_two = Dense(channel,
              kernel_initializer='he_normal',
              use_bias=True,
              bias_initializer='zeros')

  avg_pool = GlobalAveragePooling2D()(x)    
  avg_pool = Reshape((1,1,channel))(avg_pool)
  assert avg_pool.shape[1:] == (1,1,channel)
  avg_pool = shared_layer_one(avg_pool)
  assert avg_pool.shape[1:] == (1,1,channel//ratio)
  avg_pool = shared_layer_two(avg_pool)
  assert avg_pool.shape[1:] == (1,1,channel)

  max_pool = GlobalMaxPooling2D()(x)
  max_pool = Reshape((1,1,channel))(max_pool)
  assert max_pool.shape[1:] == (1,1,channel)
  max_pool = shared_layer_one(max_pool)
  assert max_pool.shape[1:] == (1,1,channel//ratio)
  max_pool = shared_layer_two(max_pool)
  assert max_pool.shape[1:] == (1,1,channel)

  avg_pool1 = GlobalAveragePooling2D()(x2)    
  avg_pool1 = Reshape((1,1,channel))(avg_pool1)
  assert avg_pool1.shape[1:] == (1,1,channel)
  avg_pool1 = shared_layer_one(avg_pool1)
  assert avg_pool1.shape[1:] == (1,1,channel//ratio)
  avg_pool1 = shared_layer_two(avg_pool1)
  assert avg_pool1.shape[1:] == (1,1,channel)

  max_pool1 = GlobalMaxPooling2D()(x2)
  max_pool1 = Reshape((1,1,channel))(max_pool1)
  assert max_pool1.shape[1:] == (1,1,channel)
  max_pool1 = shared_layer_one(max_pool1)
  assert max_pool1.shape[1:] == (1,1,channel//ratio)
  max_pool1 = shared_layer_two(max_pool1)
  assert max_pool1.shape[1:] == (1,1,channel)

  concat = Concatenate(axis=3)([avg_pool, max_pool, avg_pool1, max_pool1])
  print('concat', concat)
  print('avg_pool',avg_pool)
  cbam_feature=Dense(x.shape[3])(concat)
  print ('after dense1',cbam_feature)
  cbam_feature = Activation('relu')(cbam_feature)
  cbam_feature=Dense(x.shape[3])(concat)
  print ('after dense2',cbam_feature)
  #sum = Add()([avg_pool,max_pool,avg_pool1,max_pool1])
  #print ('sum', sum)
  cbam_feature = Activation('sigmoid')(cbam_feature)
  print (cbam_feature)
  if K.image_data_format() == "channels_first":
    cbam_feature = Permute((3, 1, 2))(cbam_feature)
  
  return multiply([x, cbam_feature])

def spatial_attention2(x,x1):
  kernel_size = 7
	
  if K.image_data_format() == "channels_first":
    channel = x.shape[1]
    cbam_feature = Permute((2,3,1))(x)
  else:
    channel = x.shape[-1]
    cbam_feature = x
	
  avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(cbam_feature)
  print ('avg pool v1',avg_pool)
  assert avg_pool.shape[-1] == 1
  max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(cbam_feature)
  assert max_pool.shape[-1] == 1

  if K.image_data_format() == "channels_first":
    channel = x1.shape[1]
    cbam_feature = Permute((2,3,1))(x1)
  else:
    channel = x1.shape[-1]
    cbam_feature = x1

  avg_pool1 = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(x1)
  print ('avg pool v2',avg_pool1)
  assert avg_pool1.shape[-1] == 1
  max_pool1 = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(x1)
  assert max_pool1.shape[-1] == 1

  concat = Concatenate(axis=3)([avg_pool, max_pool, avg_pool1, max_pool1])
  #concat = Concatenate(axis=3)([avg_pool, max_pool])
  assert concat.shape[-1] == 4
  cbam_feature = Conv2D(4, (3, 3), padding="same")(concat)
  cbam_feature = Activation('relu')(cbam_feature)	
  cbam_feature = Conv2D(1, (3, 3), padding="same")(cbam_feature)
  cbam_feature = Activation('sigmoid')(cbam_feature)
  print (cbam_feature)	
  assert cbam_feature.shape[-1] == 1
  if K.image_data_format() == "channels_first":
    cbam_feature = Permute((3, 1, 2))(cbam_feature)
  print (multiply([x, cbam_feature]))
  return multiply([x, cbam_feature])

# %%
def MyResNet50(dimension,include_top=True, weights='imagenet',
             input_tensor=None, input_shape=None,
             pooling=None,
             classes=1):
    """Instantiates the ResNet50 architecture.
    Optionally loads weights pre-trained
    on ImageNet. Note that when using TensorFlow,
    for best performance you should set
    `image_data_format="channels_last"` in your Keras config
    at ~/.keras/keras.json.
    The model and the weights are compatible with both
    TensorFlow and Theano. The data format
    convention used by the model is the one
    specified in your Keras config file.
    # Arguments
        include_top: whether to include the fully-connected
            layer at the top of the network.
        weights: one of `None` (random initialization)
            or "imagenet" (pre-training on ImageNet).
        input_tensor: optional Keras tensor (i.e. output of `layers.Input()`)
            to use as image input for the model.
        input_shape: optional shape tuple, only to be specified
            if `include_top` is False (otherwise the input shape
            has to be `(224, 224, 3)` (with `channels_last` data format)
            or `(3, 224, 244)` (with `channels_first` data format).
            It should have exactly 3 inputs channels,
            and width and height should be no smaller than 197.
            E.g. `(200, 200, 3)` would be one valid value.
        pooling: Optional pooling mode for feature extraction
            when `include_top` is `False`.
            - `None` means that the output of the model will be
                the 4D tensor output of the
                last convolutional layer.
            - `avg` means that global average pooling
                will be applied to the output of the
                last convolutional layer, and thus
                the output of the model will be a 2D tensor.
            - `max` means that global max pooling will
                be applied.
        classes: optional number of classes to classify images
            into, only to be specified if `include_top` is True, and
            if no `weights` argument is specified.
    # Returns
        A Keras model instance.
    # Raises
        ValueError: in case of invalid argument for `weights`,
            or invalid input shape.
    """
    if weights not in {'imagenet', None}:
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `imagenet` '
                         '(pre-training on ImageNet).')

    if weights == 'imagenet' and include_top and classes != 1000:
        raise ValueError('If using `weights` as imagenet with `include_top`'
                         ' as true, `classes` should be 1000')
    #######################################
    ##### Determine proper input shape ####
    #######################################
    input_shape = [dimension[0],dimension[1],3,3]
    #print (input_tensor)
    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor
    if K.image_data_format() == 'channels_last':
        bn_axis = 3
    else:
        bn_axis = 1
    
    print ('before',img_input)
    #input_tensor=input_tensor[:,:,:,:,0]
    x=img_input[:,:,:,:,0]
    x1=img_input[:,:,:,:,1]
    x2=img_input[:,:,:,:,2]
    #x3=img_input[:,:,:,:,3]

    print ('after',x)
    x = ZeroPadding2D((3, 3))(x)
    x1 = ZeroPadding2D((3, 3))(x1)
    x2 = ZeroPadding2D((3, 3))(x2)
    #x3 = ZeroPadding2D((3, 3))(x3)
    print ('first', x)
    x = Conv2D(64, (7, 7), strides=(2, 2), name='conv1')(x)
    x1 = Conv2D(64, (7, 7), strides=(2, 2), name='conv1_1')(x1)
    x2 = Conv2D(64, (7, 7), strides=(2, 2), name='conv1_2')(x2)
    #x3 = Conv2D(64, (7, 7), strides=(2, 2), name='conv1_3')(x3)

    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x1 = BatchNormalization(axis=bn_axis, name='bn_conv1_1')(x1)
    x2 = BatchNormalization(axis=bn_axis, name='bn_conv1_2')(x2)
    #x3 = BatchNormalization(axis=bn_axis, name='bn_conv1_3')(x3)

    x = Activation('relu')(x)
    x1 = Activation('relu')(x1)
    x2 = Activation('relu')(x2)
    #x3 = Activation('relu')(x3)

    x = MaxPooling2D((3, 3), strides=(2, 2))(x)
    x1 = MaxPooling2D((3, 3), strides=(2, 2))(x1)
    x2 = MaxPooling2D((3, 3), strides=(2, 2))(x2)
    #x3 = MaxPooling2D((3, 3), strides=(2, 2))(x3)

    x = conv_block(x, 3, [64, 64, 256], stage=2, block='a', strides=(1, 1))
    x1 = conv_block(x1, 3, [64, 64, 256], stage=2, block='a1', strides=(1, 1))
    x2 = conv_block(x2, 3, [64, 64, 256], stage=2, block='a2', strides=(1, 1))
    #x3 = conv_block(x3, 3, [64, 64, 256], stage=2, block='a3', strides=(1, 1))

    x = identity_block(x, 3, [64, 64, 256], stage=2, block='b')
    x1 = identity_block(x1, 3, [64, 64, 256], stage=2, block='b1')
    x2 = identity_block(x2, 3, [64, 64, 256], stage=2, block='b2')
    #x3 = identity_block(x3, 3, [64, 64, 256], stage=2, block='b3')

    x = identity_block(x, 3, [64, 64, 256], stage=2, block='c')
    x1 = identity_block(x1, 3, [64, 64, 256], stage=2, block='c1')
    x2 = identity_block(x2, 3, [64, 64, 256], stage=2, block='c2')
    #x3 = identity_block(x3, 3, [64, 64, 256], stage=2, block='c3')
    #print ('x1',x1.shape[3])
    
    #x = cbam_block(x)


    x = conv_block(x, 3, [128, 128, 512], stage=3, block='a')
    x1 = conv_block(x1, 3, [128, 128, 512], stage=3, block='a1')
    x2 = conv_block(x2, 3, [128, 128, 512], stage=3, block='a2')
    #x3 = conv_block(x2, 3, [128, 128, 512], stage=3, block='a3')

    x = identity_block(x, 3, [128, 128, 512], stage=3, block='b')
    x1 = identity_block(x1, 3, [128, 128, 512], stage=3, block='b1')
    x2 = identity_block(x2, 3, [128, 128, 512], stage=3, block='b2')
    #x3 = identity_block(x3, 3, [128, 128, 512], stage=3, block='b3')

    x = identity_block(x, 3, [128, 128, 512], stage=3, block='c')
    x1 = identity_block(x1, 3, [128, 128, 512], stage=3, block='c1')
    x2 = identity_block(x2, 3, [128, 128, 512], stage=3, block='c2')
    #x3 = identity_block(x3, 3, [128, 128, 512], stage=3, block='c3')

    x = identity_block(x, 3, [128, 128, 512], stage=3, block='d')
    x1 = identity_block(x1, 3, [128, 128, 512], stage=3, block='d1')
    x2 = identity_block(x2, 3, [128, 128, 512], stage=3, block='d2')
    #x3 = identity_block(x3, 3, [128, 128, 512], stage=3, block='d3')

    #x = cbam_block(x)

    x = cvam_block(x,x1,x2)
    #x1 = cvam_block(x1,x,x3)
    # x2 = cvam_block(x2,x3,x)
    # x3 = cvam_block(x3,x2,x1)

    x = conv_block(x, 3, [256, 256, 1024], stage=4, block='a')
    x1 = conv_block(x1, 3, [256, 256, 1024], stage=4, block='a1')
    x2 = conv_block(x2, 3, [256, 256, 1024], stage=4, block='a2')
    #x3 = conv_block(x3, 3, [256, 256, 1024], stage=4, block='a3')

    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='b')
    x1 = identity_block(x1, 3, [256, 256, 1024], stage=4, block='b1')
    x2 = identity_block(x2, 3, [256, 256, 1024], stage=4, block='b2')
    #x3 = identity_block(x3, 3, [256, 256, 1024], stage=4, block='b3')

    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='c')
    x1 = identity_block(x1, 3, [256, 256, 1024], stage=4, block='c1')
    x2 = identity_block(x2, 3, [256, 256, 1024], stage=4, block='c2')
    #x3 = identity_block(x3, 3, [256, 256, 1024], stage=4, block='c3')

    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='d')
    x1 = identity_block(x1, 3, [256, 256, 1024], stage=4, block='d1')
    x2 = identity_block(x2, 3, [256, 256, 1024], stage=4, block='d2')
    #x3 = identity_block(x3, 3, [256, 256, 1024], stage=4, block='d3')

    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='e')
    x1 = identity_block(x1, 3, [256, 256, 1024], stage=4, block='e1')
    x2 = identity_block(x2, 3, [256, 256, 1024], stage=4, block='e2')
    #x3 = identity_block(x3, 3, [256, 256, 1024], stage=4, block='e3')

    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='f')
    x1 = identity_block(x1, 3, [256, 256, 1024], stage=4, block='f1')
    x2 = identity_block(x2, 3, [256, 256, 1024], stage=4, block='f2')
    #x3 = identity_block(x3, 3, [256, 256, 1024], stage=4, block='f3')

    #x = cbam_block(x)
    x = cvam_block(x,x1,x2)
    #x1 = cvam_block(x1,x,x3)
    # x2 = cvam_block(x2,x3,x)
    # x3 = cvam_block(x3,x2,x1)

    x = conv_block(x, 3, [512, 512, 2048], stage=5, block='a')
    x1 = conv_block(x1, 3, [512, 512, 2048], stage=5, block='a1')
    x2 = conv_block(x2, 3, [512, 512, 2048], stage=5, block='a2')
    #x3 = conv_block(x3, 3, [512, 512, 2048], stage=5, block='a3')

    x = identity_block(x, 3, [512, 512, 2048], stage=5, block='b')
    x1 = identity_block(x1, 3, [512, 512, 2048], stage=5, block='b1')
    x2 = identity_block(x2, 3, [512, 512, 2048], stage=5, block='b2')
    #x3 = identity_block(x3, 3, [512, 512, 2048], stage=5, block='b3')

    x = identity_block(x, 3, [512, 512, 2048], stage=5, block='c')
    x1 = identity_block(x1, 3, [512, 512, 2048], stage=5, block='c1')
    x2 = identity_block(x2, 3, [512, 512, 2048], stage=5, block='c2')
    #x3 = identity_block(x3, 3, [512, 512, 2048], stage=5, block='c3')

    #x = cbam_block(x)
    x = cvam_block(x,x1,x2)
    #x1 = cvam_block(x1,x,x3)
    # x2 = cvam_block(x2,x3,x)
    # x3 = cvam_block(x3,x2,x1)

    x = GlobalAveragePooling2D()(x)

   #print (x.index)
    #x = AveragePooling2D((7, 7), name='avg_pool')(x)

    # if include_top:
    #     x = Flatten()(x)
    #     x = Dense(classes, activation='softmax', name='fc1000')(x)
    # else:
    #     if pooling == 'avg':
    #         x = GlobalAveragePooling2D()(x)
    #     elif pooling == 'max':
    #         x = GlobalMaxPooling2D()(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    print (input_tensor, img_input)
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input
    # Create model.
    model = Model(inputs=inputs, outputs=x, name='resnet50')

    # load weights
    if weights == 'imagenet':
        if include_top:
            weights_path = get_file('resnet50_weights_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH,
                                    cache_subdir='models',
                                    md5_hash='a7b3fe01876f51b976af0dea6bc144eb')
        else:
            weights_path = get_file('resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5',
                                    WEIGHTS_PATH_NO_TOP,
                                    cache_subdir='models',
                                    md5_hash='a268eb855778b3df3c7506639542a6af')
        model.load_weights(weights_path, by_name = True, skip_mismatch = True)
        if K.backend() == 'theano':
            layer_utils.convert_all_kernels_in_model(model)

        if K.image_data_format() == 'channels_first':
            if include_top:
                maxpool = model.get_layer(name='avg_pool')
                shape = maxpool.output_shape[1:]
                dense = model.get_layer(name='fc1000')
                layer_utils.convert_dense_weights_data_format(dense, shape, 'channels_first')

            if K.backend() == 'tensorflow':
                warnings.warn('You are using the TensorFlow backend, yet you ')
    return model

# %%
base_model = MyResNet50(dim,weights='imagenet', include_top=False)
base_model.summary()
# Out:
# before KerasTensor(type_spec=TensorSpec(shape=(None, 600, 300, 3, 3), dtype=tf.float32, name='input_6'), name='input_6', description="created by layer 'input_6'")
# after KerasTensor(type_spec=TensorSpec(shape=(None, 600, 300, 3), dtype=tf.float32, name=None), name='tf.__operators__.getitem_4/strided_slice:0', description="created by layer 'tf.__operators__.getitem_4'")
# first KerasTensor(type_spec=TensorSpec(shape=(None, 606, 306, 3), dtype=tf.float32, name=None), name='zero_padding2d_9/Pad:0', description="created by layer 'zero_padding2d_9'")
# before KerasTensor(type_spec=TensorSpec(shape=(None, 75, 37, 512), dtype=tf.float32, name=None), name='activation_308/Relu:0', description="created by layer 'activation_308'")
# concat KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 2048), dtype=tf.float32, name=None), name='concatenate_8/concat:0', description="created by layer 'concatenate_8'")
# avg_pool KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 512), dtype=tf.float32, name=None), name='dense_19/BiasAdd:0', description="created by layer 'dense_19'")
# after dense1 KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 512), dtype=tf.float32, name=None), name='dense_20/BiasAdd:0', description="created by layer 'dense_20'")
# after dense2 KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 512), dtype=tf.float32, name=None), name='dense_21/BiasAdd:0', description="created by layer 'dense_21'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 512), dtype=tf.float32, name=None), name='activation_316/Sigmoid:0', description="created by layer 'activation_316'")
# after KerasTensor(type_spec=TensorSpec(shape=(None, 75, 37, 512), dtype=tf.float32, name=None), name='multiply_10/mul:0', description="created by layer 'multiply_10'")
# avg pool v1 KerasTensor(type_spec=TensorSpec(shape=(None, 75, 37, 1), dtype=tf.float32, name=None), name='lambda_16/Mean:0', description="created by layer 'lambda_16'")
# avg pool v2 KerasTensor(type_spec=TensorSpec(shape=(None, 75, 37, 1), dtype=tf.float32, name=None), name='lambda_18/Mean:0', description="created by layer 'lambda_18'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 75, 37, 1), dtype=tf.float32, name=None), name='activation_318/Sigmoid:0', description="created by layer 'activation_318'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 75, 37, 512), dtype=tf.float32, name=None), name='multiply_11/mul:0', description="created by layer 'multiply_11'")
# before KerasTensor(type_spec=TensorSpec(shape=(None, 38, 19, 1024), dtype=tf.float32, name=None), name='activation_366/Relu:0', description="created by layer 'activation_366'")
# concat KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 4096), dtype=tf.float32, name=None), name='concatenate_10/concat:0', description="created by layer 'concatenate_10'")
# avg_pool KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 1024), dtype=tf.float32, name=None), name='dense_23/BiasAdd:0', description="created by layer 'dense_23'")
# after dense1 KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 1024), dtype=tf.float32, name=None), name='dense_24/BiasAdd:0', description="created by layer 'dense_24'")
# after dense2 KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 1024), dtype=tf.float32, name=None), name='dense_25/BiasAdd:0', description="created by layer 'dense_25'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 1024), dtype=tf.float32, name=None), name='activation_374/Sigmoid:0', description="created by layer 'activation_374'")
# after KerasTensor(type_spec=TensorSpec(shape=(None, 38, 19, 1024), dtype=tf.float32, name=None), name='multiply_13/mul:0', description="created by layer 'multiply_13'")
# avg pool v1 KerasTensor(type_spec=TensorSpec(shape=(None, 38, 19, 1), dtype=tf.float32, name=None), name='lambda_20/Mean:0', description="created by layer 'lambda_20'")
# avg pool v2 KerasTensor(type_spec=TensorSpec(shape=(None, 38, 19, 1), dtype=tf.float32, name=None), name='lambda_22/Mean:0', description="created by layer 'lambda_22'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 38, 19, 1), dtype=tf.float32, name=None), name='activation_376/Sigmoid:0', description="created by layer 'activation_376'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 38, 19, 1024), dtype=tf.float32, name=None), name='multiply_14/mul:0', description="created by layer 'multiply_14'")
# before KerasTensor(type_spec=TensorSpec(shape=(None, 19, 10, 2048), dtype=tf.float32, name=None), name='activation_397/Relu:0', description="created by layer 'activation_397'")
# concat KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 8192), dtype=tf.float32, name=None), name='concatenate_12/concat:0', description="created by layer 'concatenate_12'")
# avg_pool KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 2048), dtype=tf.float32, name=None), name='dense_27/BiasAdd:0', description="created by layer 'dense_27'")
# after dense1 KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 2048), dtype=tf.float32, name=None), name='dense_28/BiasAdd:0', description="created by layer 'dense_28'")
# after dense2 KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 2048), dtype=tf.float32, name=None), name='dense_29/BiasAdd:0', description="created by layer 'dense_29'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 2048), dtype=tf.float32, name=None), name='activation_405/Sigmoid:0', description="created by layer 'activation_405'")
# after KerasTensor(type_spec=TensorSpec(shape=(None, 19, 10, 2048), dtype=tf.float32, name=None), name='multiply_16/mul:0', description="created by layer 'multiply_16'")
# avg pool v1 KerasTensor(type_spec=TensorSpec(shape=(None, 19, 10, 1), dtype=tf.float32, name=None), name='lambda_24/Mean:0', description="created by layer 'lambda_24'")
# avg pool v2 KerasTensor(type_spec=TensorSpec(shape=(None, 19, 10, 1), dtype=tf.float32, name=None), name='lambda_26/Mean:0', description="created by layer 'lambda_26'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 19, 10, 1), dtype=tf.float32, name=None), name='activation_407/Sigmoid:0', description="created by layer 'activation_407'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 19, 10, 2048), dtype=tf.float32, name=None), name='multiply_17/mul:0', description="created by layer 'multiply_17'")
# None KerasTensor(type_spec=TensorSpec(shape=(None, 600, 300, 3, 3), dtype=tf.float32, name='input_6'), name='input_6', description="created by layer 'input_6'")
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 600, 300, 3, 0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_4 (Sli (None, 600, 300, 3)  0           input_6[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_6 (Sli (None, 600, 300, 3)  0           input_6[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 606, 306, 3)  0           tf.__operators__.getitem_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 606, 306, 3)  0           tf.__operators__.getitem_6[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 300, 150, 64) 9472        zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# conv1_2 (Conv2D)                (None, 300, 150, 64) 9472        zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 300, 150, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# bn_conv1_2 (BatchNormalization) (None, 300, 150, 64) 256         conv1_2[0][0]
# __________________________________________________________________________________________________
# activation_249 (Activation)     (None, 300, 150, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# activation_251 (Activation)     (None, 300, 150, 64) 0           bn_conv1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 149, 74, 64)  0           activation_249[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 149, 74, 64)  0           activation_251[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 149, 74, 64)  4160        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# res2a2_branch2a (Conv2D)        (None, 149, 74, 64)  4160        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 149, 74, 64)  256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# bn2a2_branch2a (BatchNormalizat (None, 149, 74, 64)  256         res2a2_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_252 (Activation)     (None, 149, 74, 64)  0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_258 (Activation)     (None, 149, 74, 64)  0           bn2a2_branch2a[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_5 (Sli (None, 600, 300, 3)  0           input_6[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 149, 74, 64)  36928       activation_252[0][0]
# __________________________________________________________________________________________________
# res2a2_branch2b (Conv2D)        (None, 149, 74, 64)  36928       activation_258[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 606, 306, 3)  0           tf.__operators__.getitem_5[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 149, 74, 64)  256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2a2_branch2b (BatchNormalizat (None, 149, 74, 64)  256         res2a2_branch2b[0][0]
# __________________________________________________________________________________________________
# conv1_1 (Conv2D)                (None, 300, 150, 64) 9472        zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# activation_253 (Activation)     (None, 149, 74, 64)  0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_259 (Activation)     (None, 149, 74, 64)  0           bn2a2_branch2b[0][0]
# __________________________________________________________________________________________________
# bn_conv1_1 (BatchNormalization) (None, 300, 150, 64) 256         conv1_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 149, 74, 256) 16640       activation_253[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 149, 74, 256) 16640       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# res2a2_branch2c (Conv2D)        (None, 149, 74, 256) 16640       activation_259[0][0]
# __________________________________________________________________________________________________
# res2a2_branch1 (Conv2D)         (None, 149, 74, 256) 16640       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# activation_250 (Activation)     (None, 300, 150, 64) 0           bn_conv1_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 149, 74, 256) 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 149, 74, 256) 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# bn2a2_branch2c (BatchNormalizat (None, 149, 74, 256) 1024        res2a2_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a2_branch1 (BatchNormalizati (None, 149, 74, 256) 1024        res2a2_branch1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 149, 74, 64)  0           activation_250[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 149, 74, 256) 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 149, 74, 256) 0           bn2a2_branch2c[0][0]
#                                                                  bn2a2_branch1[0][0]
# __________________________________________________________________________________________________
# res2a1_branch2a (Conv2D)        (None, 149, 74, 64)  4160        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# activation_254 (Activation)     (None, 149, 74, 256) 0           add_76[0][0]
# __________________________________________________________________________________________________
# activation_260 (Activation)     (None, 149, 74, 256) 0           add_78[0][0]
# __________________________________________________________________________________________________
# bn2a1_branch2a (BatchNormalizat (None, 149, 74, 64)  256         res2a1_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 149, 74, 64)  16448       activation_254[0][0]
# __________________________________________________________________________________________________
# res2b2_branch2a (Conv2D)        (None, 149, 74, 64)  16448       activation_260[0][0]
# __________________________________________________________________________________________________
# activation_255 (Activation)     (None, 149, 74, 64)  0           bn2a1_branch2a[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 149, 74, 64)  256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# bn2b2_branch2a (BatchNormalizat (None, 149, 74, 64)  256         res2b2_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a1_branch2b (Conv2D)        (None, 149, 74, 64)  36928       activation_255[0][0]
# __________________________________________________________________________________________________
# activation_261 (Activation)     (None, 149, 74, 64)  0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_267 (Activation)     (None, 149, 74, 64)  0           bn2b2_branch2a[0][0]
# __________________________________________________________________________________________________
# bn2a1_branch2b (BatchNormalizat (None, 149, 74, 64)  256         res2a1_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 149, 74, 64)  36928       activation_261[0][0]
# __________________________________________________________________________________________________
# res2b2_branch2b (Conv2D)        (None, 149, 74, 64)  36928       activation_267[0][0]
# __________________________________________________________________________________________________
# activation_256 (Activation)     (None, 149, 74, 64)  0           bn2a1_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 149, 74, 64)  256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2b2_branch2b (BatchNormalizat (None, 149, 74, 64)  256         res2b2_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a1_branch2c (Conv2D)        (None, 149, 74, 256) 16640       activation_256[0][0]
# __________________________________________________________________________________________________
# res2a1_branch1 (Conv2D)         (None, 149, 74, 256) 16640       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# activation_262 (Activation)     (None, 149, 74, 64)  0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_268 (Activation)     (None, 149, 74, 64)  0           bn2b2_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2a1_branch2c (BatchNormalizat (None, 149, 74, 256) 1024        res2a1_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a1_branch1 (BatchNormalizati (None, 149, 74, 256) 1024        res2a1_branch1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 149, 74, 256) 16640       activation_262[0][0]
# __________________________________________________________________________________________________
# res2b2_branch2c (Conv2D)        (None, 149, 74, 256) 16640       activation_268[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 149, 74, 256) 0           bn2a1_branch2c[0][0]
#                                                                  bn2a1_branch1[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 149, 74, 256) 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2b2_branch2c (BatchNormalizat (None, 149, 74, 256) 1024        res2b2_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_257 (Activation)     (None, 149, 74, 256) 0           add_77[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 149, 74, 256) 0           bn2b_branch2c[0][0]
#                                                                  activation_254[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 149, 74, 256) 0           bn2b2_branch2c[0][0]
#                                                                  activation_260[0][0]
# __________________________________________________________________________________________________
# res2b1_branch2a (Conv2D)        (None, 149, 74, 64)  16448       activation_257[0][0]
# __________________________________________________________________________________________________
# activation_263 (Activation)     (None, 149, 74, 256) 0           add_79[0][0]
# __________________________________________________________________________________________________
# activation_269 (Activation)     (None, 149, 74, 256) 0           add_81[0][0]
# __________________________________________________________________________________________________
# bn2b1_branch2a (BatchNormalizat (None, 149, 74, 64)  256         res2b1_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 149, 74, 64)  16448       activation_263[0][0]
# __________________________________________________________________________________________________
# res2c2_branch2a (Conv2D)        (None, 149, 74, 64)  16448       activation_269[0][0]
# __________________________________________________________________________________________________
# activation_264 (Activation)     (None, 149, 74, 64)  0           bn2b1_branch2a[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 149, 74, 64)  256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# bn2c2_branch2a (BatchNormalizat (None, 149, 74, 64)  256         res2c2_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b1_branch2b (Conv2D)        (None, 149, 74, 64)  36928       activation_264[0][0]
# __________________________________________________________________________________________________
# activation_270 (Activation)     (None, 149, 74, 64)  0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_276 (Activation)     (None, 149, 74, 64)  0           bn2c2_branch2a[0][0]
# __________________________________________________________________________________________________
# bn2b1_branch2b (BatchNormalizat (None, 149, 74, 64)  256         res2b1_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 149, 74, 64)  36928       activation_270[0][0]
# __________________________________________________________________________________________________
# res2c2_branch2b (Conv2D)        (None, 149, 74, 64)  36928       activation_276[0][0]
# __________________________________________________________________________________________________
# activation_265 (Activation)     (None, 149, 74, 64)  0           bn2b1_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 149, 74, 64)  256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2c2_branch2b (BatchNormalizat (None, 149, 74, 64)  256         res2c2_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b1_branch2c (Conv2D)        (None, 149, 74, 256) 16640       activation_265[0][0]
# __________________________________________________________________________________________________
# activation_271 (Activation)     (None, 149, 74, 64)  0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_277 (Activation)     (None, 149, 74, 64)  0           bn2c2_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2b1_branch2c (BatchNormalizat (None, 149, 74, 256) 1024        res2b1_branch2c[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 149, 74, 256) 16640       activation_271[0][0]
# __________________________________________________________________________________________________
# res2c2_branch2c (Conv2D)        (None, 149, 74, 256) 16640       activation_277[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 149, 74, 256) 0           bn2b1_branch2c[0][0]
#                                                                  activation_257[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 149, 74, 256) 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2c2_branch2c (BatchNormalizat (None, 149, 74, 256) 1024        res2c2_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_266 (Activation)     (None, 149, 74, 256) 0           add_80[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 149, 74, 256) 0           bn2c_branch2c[0][0]
#                                                                  activation_263[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 149, 74, 256) 0           bn2c2_branch2c[0][0]
#                                                                  activation_269[0][0]
# __________________________________________________________________________________________________
# res2c1_branch2a (Conv2D)        (None, 149, 74, 64)  16448       activation_266[0][0]
# __________________________________________________________________________________________________
# activation_272 (Activation)     (None, 149, 74, 256) 0           add_82[0][0]
# __________________________________________________________________________________________________
# activation_278 (Activation)     (None, 149, 74, 256) 0           add_84[0][0]
# __________________________________________________________________________________________________
# bn2c1_branch2a (BatchNormalizat (None, 149, 74, 64)  256         res2c1_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 75, 37, 128)  32896       activation_272[0][0]
# __________________________________________________________________________________________________
# res3a2_branch2a (Conv2D)        (None, 75, 37, 128)  32896       activation_278[0][0]
# __________________________________________________________________________________________________
# activation_273 (Activation)     (None, 149, 74, 64)  0           bn2c1_branch2a[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 75, 37, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# bn3a2_branch2a (BatchNormalizat (None, 75, 37, 128)  512         res3a2_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c1_branch2b (Conv2D)        (None, 149, 74, 64)  36928       activation_273[0][0]
# __________________________________________________________________________________________________
# activation_279 (Activation)     (None, 75, 37, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_285 (Activation)     (None, 75, 37, 128)  0           bn3a2_branch2a[0][0]
# __________________________________________________________________________________________________
# bn2c1_branch2b (BatchNormalizat (None, 149, 74, 64)  256         res2c1_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 75, 37, 128)  147584      activation_279[0][0]
# __________________________________________________________________________________________________
# res3a2_branch2b (Conv2D)        (None, 75, 37, 128)  147584      activation_285[0][0]
# __________________________________________________________________________________________________
# activation_274 (Activation)     (None, 149, 74, 64)  0           bn2c1_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 75, 37, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3a2_branch2b (BatchNormalizat (None, 75, 37, 128)  512         res3a2_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c1_branch2c (Conv2D)        (None, 149, 74, 256) 16640       activation_274[0][0]
# __________________________________________________________________________________________________
# activation_280 (Activation)     (None, 75, 37, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_286 (Activation)     (None, 75, 37, 128)  0           bn3a2_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2c1_branch2c (BatchNormalizat (None, 149, 74, 256) 1024        res2c1_branch2c[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 75, 37, 512)  66048       activation_280[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 75, 37, 512)  131584      activation_272[0][0]
# __________________________________________________________________________________________________
# res3a2_branch2c (Conv2D)        (None, 75, 37, 512)  66048       activation_286[0][0]
# __________________________________________________________________________________________________
# res3a2_branch1 (Conv2D)         (None, 75, 37, 512)  131584      activation_278[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 149, 74, 256) 0           bn2c1_branch2c[0][0]
#                                                                  activation_266[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 75, 37, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 75, 37, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# bn3a2_branch2c (BatchNormalizat (None, 75, 37, 512)  2048        res3a2_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a2_branch1 (BatchNormalizati (None, 75, 37, 512)  2048        res3a2_branch1[0][0]
# __________________________________________________________________________________________________
# activation_275 (Activation)     (None, 149, 74, 256) 0           add_83[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 75, 37, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, 75, 37, 512)  0           bn3a2_branch2c[0][0]
#                                                                  bn3a2_branch1[0][0]
# __________________________________________________________________________________________________
# res3a1_branch2a (Conv2D)        (None, 75, 37, 128)  32896       activation_275[0][0]
# __________________________________________________________________________________________________
# activation_281 (Activation)     (None, 75, 37, 512)  0           add_85[0][0]
# __________________________________________________________________________________________________
# activation_287 (Activation)     (None, 75, 37, 512)  0           add_87[0][0]
# __________________________________________________________________________________________________
# bn3a1_branch2a (BatchNormalizat (None, 75, 37, 128)  512         res3a1_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 75, 37, 128)  65664       activation_281[0][0]
# __________________________________________________________________________________________________
# res3b2_branch2a (Conv2D)        (None, 75, 37, 128)  65664       activation_287[0][0]
# __________________________________________________________________________________________________
# activation_282 (Activation)     (None, 75, 37, 128)  0           bn3a1_branch2a[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 75, 37, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# bn3b2_branch2a (BatchNormalizat (None, 75, 37, 128)  512         res3b2_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a1_branch2b (Conv2D)        (None, 75, 37, 128)  147584      activation_282[0][0]
# __________________________________________________________________________________________________
# activation_288 (Activation)     (None, 75, 37, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_294 (Activation)     (None, 75, 37, 128)  0           bn3b2_branch2a[0][0]
# __________________________________________________________________________________________________
# bn3a1_branch2b (BatchNormalizat (None, 75, 37, 128)  512         res3a1_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 75, 37, 128)  147584      activation_288[0][0]
# __________________________________________________________________________________________________
# res3b2_branch2b (Conv2D)        (None, 75, 37, 128)  147584      activation_294[0][0]
# __________________________________________________________________________________________________
# activation_283 (Activation)     (None, 75, 37, 128)  0           bn3a1_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 75, 37, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3b2_branch2b (BatchNormalizat (None, 75, 37, 128)  512         res3b2_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a1_branch2c (Conv2D)        (None, 75, 37, 512)  66048       activation_283[0][0]
# __________________________________________________________________________________________________
# res3a1_branch1 (Conv2D)         (None, 75, 37, 512)  131584      activation_275[0][0]
# __________________________________________________________________________________________________
# activation_289 (Activation)     (None, 75, 37, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_295 (Activation)     (None, 75, 37, 128)  0           bn3b2_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3a1_branch2c (BatchNormalizat (None, 75, 37, 512)  2048        res3a1_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a1_branch1 (BatchNormalizati (None, 75, 37, 512)  2048        res3a1_branch1[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 75, 37, 512)  66048       activation_289[0][0]
# __________________________________________________________________________________________________
# res3b2_branch2c (Conv2D)        (None, 75, 37, 512)  66048       activation_295[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 75, 37, 512)  0           bn3a1_branch2c[0][0]
#                                                                  bn3a1_branch1[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 75, 37, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3b2_branch2c (BatchNormalizat (None, 75, 37, 512)  2048        res3b2_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_284 (Activation)     (None, 75, 37, 512)  0           add_86[0][0]
# __________________________________________________________________________________________________
# add_88 (Add)                    (None, 75, 37, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_281[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, 75, 37, 512)  0           bn3b2_branch2c[0][0]
#                                                                  activation_287[0][0]
# __________________________________________________________________________________________________
# res3b1_branch2a (Conv2D)        (None, 75, 37, 128)  65664       activation_284[0][0]
# __________________________________________________________________________________________________
# activation_290 (Activation)     (None, 75, 37, 512)  0           add_88[0][0]
# __________________________________________________________________________________________________
# activation_296 (Activation)     (None, 75, 37, 512)  0           add_90[0][0]
# __________________________________________________________________________________________________
# bn3b1_branch2a (BatchNormalizat (None, 75, 37, 128)  512         res3b1_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 75, 37, 128)  65664       activation_290[0][0]
# __________________________________________________________________________________________________
# res3c2_branch2a (Conv2D)        (None, 75, 37, 128)  65664       activation_296[0][0]
# __________________________________________________________________________________________________
# activation_291 (Activation)     (None, 75, 37, 128)  0           bn3b1_branch2a[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 75, 37, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# bn3c2_branch2a (BatchNormalizat (None, 75, 37, 128)  512         res3c2_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b1_branch2b (Conv2D)        (None, 75, 37, 128)  147584      activation_291[0][0]
# __________________________________________________________________________________________________
# activation_297 (Activation)     (None, 75, 37, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_303 (Activation)     (None, 75, 37, 128)  0           bn3c2_branch2a[0][0]
# __________________________________________________________________________________________________
# bn3b1_branch2b (BatchNormalizat (None, 75, 37, 128)  512         res3b1_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 75, 37, 128)  147584      activation_297[0][0]
# __________________________________________________________________________________________________
# res3c2_branch2b (Conv2D)        (None, 75, 37, 128)  147584      activation_303[0][0]
# __________________________________________________________________________________________________
# activation_292 (Activation)     (None, 75, 37, 128)  0           bn3b1_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 75, 37, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3c2_branch2b (BatchNormalizat (None, 75, 37, 128)  512         res3c2_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b1_branch2c (Conv2D)        (None, 75, 37, 512)  66048       activation_292[0][0]
# __________________________________________________________________________________________________
# activation_298 (Activation)     (None, 75, 37, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_304 (Activation)     (None, 75, 37, 128)  0           bn3c2_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3b1_branch2c (BatchNormalizat (None, 75, 37, 512)  2048        res3b1_branch2c[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 75, 37, 512)  66048       activation_298[0][0]
# __________________________________________________________________________________________________
# res3c2_branch2c (Conv2D)        (None, 75, 37, 512)  66048       activation_304[0][0]
# __________________________________________________________________________________________________
# add_89 (Add)                    (None, 75, 37, 512)  0           bn3b1_branch2c[0][0]
#                                                                  activation_284[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 75, 37, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3c2_branch2c (BatchNormalizat (None, 75, 37, 512)  2048        res3c2_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_293 (Activation)     (None, 75, 37, 512)  0           add_89[0][0]
# __________________________________________________________________________________________________
# add_91 (Add)                    (None, 75, 37, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_290[0][0]
# __________________________________________________________________________________________________
# add_93 (Add)                    (None, 75, 37, 512)  0           bn3c2_branch2c[0][0]
#                                                                  activation_296[0][0]
# __________________________________________________________________________________________________
# res3c1_branch2a (Conv2D)        (None, 75, 37, 128)  65664       activation_293[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# add_118 (Add)                   (None, 19, 10, 2048) 0           bn5b_branch2c[0][0]
#                                                                  activation_379[0][0]
# __________________________________________________________________________________________________
# add_120 (Add)                   (None, 19, 10, 2048) 0           bn5b2_branch2c[0][0]
#                                                                  activation_385[0][0]
# __________________________________________________________________________________________________
# res5b1_branch2a (Conv2D)        (None, 19, 10, 512)  1049088     activation_382[0][0]
# __________________________________________________________________________________________________
# activation_388 (Activation)     (None, 19, 10, 2048) 0           add_118[0][0]
# __________________________________________________________________________________________________
# activation_394 (Activation)     (None, 19, 10, 2048) 0           add_120[0][0]
# __________________________________________________________________________________________________
# bn5b1_branch2a (BatchNormalizat (None, 19, 10, 512)  2048        res5b1_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 19, 10, 512)  1049088     activation_388[0][0]
# __________________________________________________________________________________________________
# res5c2_branch2a (Conv2D)        (None, 19, 10, 512)  1049088     activation_394[0][0]
# __________________________________________________________________________________________________
# activation_389 (Activation)     (None, 19, 10, 512)  0           bn5b1_branch2a[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 19, 10, 512)  2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# bn5c2_branch2a (BatchNormalizat (None, 19, 10, 512)  2048        res5c2_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b1_branch2b (Conv2D)        (None, 19, 10, 512)  2359808     activation_389[0][0]
# __________________________________________________________________________________________________
# activation_395 (Activation)     (None, 19, 10, 512)  0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_401 (Activation)     (None, 19, 10, 512)  0           bn5c2_branch2a[0][0]
# __________________________________________________________________________________________________
# bn5b1_branch2b (BatchNormalizat (None, 19, 10, 512)  2048        res5b1_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 19, 10, 512)  2359808     activation_395[0][0]
# __________________________________________________________________________________________________
# res5c2_branch2b (Conv2D)        (None, 19, 10, 512)  2359808     activation_401[0][0]
# __________________________________________________________________________________________________
# activation_390 (Activation)     (None, 19, 10, 512)  0           bn5b1_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 19, 10, 512)  2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5c2_branch2b (BatchNormalizat (None, 19, 10, 512)  2048        res5c2_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b1_branch2c (Conv2D)        (None, 19, 10, 2048) 1050624     activation_390[0][0]
# __________________________________________________________________________________________________
# activation_396 (Activation)     (None, 19, 10, 512)  0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_402 (Activation)     (None, 19, 10, 512)  0           bn5c2_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5b1_branch2c (BatchNormalizat (None, 19, 10, 2048) 8192        res5b1_branch2c[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 19, 10, 2048) 1050624     activation_396[0][0]
# __________________________________________________________________________________________________
# res5c2_branch2c (Conv2D)        (None, 19, 10, 2048) 1050624     activation_402[0][0]
# __________________________________________________________________________________________________
# add_119 (Add)                   (None, 19, 10, 2048) 0           bn5b1_branch2c[0][0]
#                                                                  activation_382[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 19, 10, 2048) 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5c2_branch2c (BatchNormalizat (None, 19, 10, 2048) 8192        res5c2_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_391 (Activation)     (None, 19, 10, 2048) 0           add_119[0][0]
# __________________________________________________________________________________________________
# add_121 (Add)                   (None, 19, 10, 2048) 0           bn5c_branch2c[0][0]
#                                                                  activation_388[0][0]
# __________________________________________________________________________________________________
# add_123 (Add)                   (None, 19, 10, 2048) 0           bn5c2_branch2c[0][0]
#                                                                  activation_394[0][0]
# __________________________________________________________________________________________________
# res5c1_branch2a (Conv2D)        (None, 19, 10, 512)  1049088     activation_391[0][0]
# __________________________________________________________________________________________________
# activation_397 (Activation)     (None, 19, 10, 2048) 0           add_121[0][0]
# __________________________________________________________________________________________________
# activation_403 (Activation)     (None, 19, 10, 2048) 0           add_123[0][0]
# __________________________________________________________________________________________________
# bn5c1_branch2a (BatchNormalizat (None, 19, 10, 512)  2048        res5c1_branch2a[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_12 (Gl (None, 2048)         0           activation_397[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_12 (Global (None, 2048)         0           activation_397[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_13 (Gl (None, 2048)         0           activation_403[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_13 (Global (None, 2048)         0           activation_403[0][0]
# __________________________________________________________________________________________________
# activation_398 (Activation)     (None, 19, 10, 512)  0           bn5c1_branch2a[0][0]
# __________________________________________________________________________________________________
# reshape_24 (Reshape)            (None, 1, 1, 2048)   0           global_average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# reshape_25 (Reshape)            (None, 1, 1, 2048)   0           global_max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# reshape_26 (Reshape)            (None, 1, 1, 2048)   0           global_average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# reshape_27 (Reshape)            (None, 1, 1, 2048)   0           global_max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# res5c1_branch2b (Conv2D)        (None, 19, 10, 512)  2359808     activation_398[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 1, 1, 256)    524544      reshape_24[0][0]
#                                                                  reshape_25[0][0]
#                                                                  reshape_26[0][0]
#                                                                  reshape_27[0][0]
# __________________________________________________________________________________________________
# bn5c1_branch2b (BatchNormalizat (None, 19, 10, 512)  2048        res5c1_branch2b[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 1, 1, 2048)   526336      dense_26[0][0]
#                                                                  dense_26[1][0]
#                                                                  dense_26[2][0]
#                                                                  dense_26[3][0]
# __________________________________________________________________________________________________
# activation_399 (Activation)     (None, 19, 10, 512)  0           bn5c1_branch2b[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 1, 1, 8192)   0           dense_27[0][0]
#                                                                  dense_27[1][0]
#                                                                  dense_27[2][0]
#                                                                  dense_27[3][0]
# __________________________________________________________________________________________________
# res5c1_branch2c (Conv2D)        (None, 19, 10, 2048) 1050624     activation_399[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 1, 1, 2048)   16779264    concatenate_12[0][0]
# __________________________________________________________________________________________________
# bn5c1_branch2c (BatchNormalizat (None, 19, 10, 2048) 8192        res5c1_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_405 (Activation)     (None, 1, 1, 2048)   0           dense_29[0][0]
# __________________________________________________________________________________________________
# add_122 (Add)                   (None, 19, 10, 2048) 0           bn5c1_branch2c[0][0]
#                                                                  activation_391[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 19, 10, 2048) 0           activation_397[0][0]
#                                                                  activation_405[0][0]
# __________________________________________________________________________________________________
# activation_400 (Activation)     (None, 19, 10, 2048) 0           add_122[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 19, 10, 1)    0           multiply_16[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 19, 10, 1)    0           multiply_16[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 19, 10, 1)    0           activation_400[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 19, 10, 1)    0           activation_400[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 19, 10, 4)    0           lambda_24[0][0]
#                                                                  lambda_25[0][0]
#                                                                  lambda_26[0][0]
#                                                                  lambda_27[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 19, 10, 4)    148         concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_406 (Activation)     (None, 19, 10, 4)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 19, 10, 1)    37          activation_406[0][0]
# __________________________________________________________________________________________________
# activation_407 (Activation)     (None, 19, 10, 1)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 19, 10, 2048) 0           multiply_16[0][0]
#                                                                  activation_407[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_14 (Gl (None, 2048)         0           multiply_18[0][0]
# ==================================================================================================
# Total params: 94,167,659
# Trainable params: 94,008,299
# Non-trainable params: 159,360
# __________________________________________________________________________________________________

# %% [markdown]
# ###########################################<br>
# ## Define Preprocessing Functions ####<br>
# ###########################################

# %%
def CropBorders(img):
    nrows, ncols = img.shape[0],img.shape[1]
    # Get the start and end rows and columns
    l_crop = int(ncols * 0.01)
    r_crop = int(ncols * (1 - 0.01))
    u_crop = int(nrows * 0.04)
    d_crop = int(nrows * (1 - 0.04))
    cropped_img = img[u_crop:d_crop, l_crop:r_crop]    
    return cropped_img

# %%
def OwnGlobalBinarise(img, thresh, maxval):       
    binarised_img = np.zeros(img.shape, np.uint8)
    binarised_img[img >= thresh] = maxval    
    return binarised_img

# %%
def OpenMask(mask, ksize=(23, 23), operation="open"):
    kernel = cv2.getStructuringElement(shape=cv2.MORPH_RECT, ksize=ksize)    
    if operation == "open":
        edited_mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
    elif operation == "close":
        edited_mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)    
    # Then dilate
    edited_mask = cv2.morphologyEx(edited_mask, cv2.MORPH_DILATE, kernel)
    return edited_mask

# %%
def SortContoursByArea(contours, reverse=True):   
    '''
    ----------
    contours : {list}
        The list of contours to sort.        
    Returns
    -------
    sorted_contours : {list}
        The list of contours sorted by contour area in descending
        order.
    bounding_boxes : {list}
        The list of bounding boxes ordered corresponding to the
        contours in `sorted_contours`.
    '''   
    # Sort contours based on contour area.
    sorted_contours = sorted(contours, key=cv2.contourArea, reverse=True)    
    # Construct the list of corresponding bounding boxes.
    bounding_boxes = [cv2.boundingRect(c) for c in sorted_contours]
    return sorted_contours, bounding_boxes

# %%
def DrawContourID(img, bounding_box, contour_id):    
    '''
    ----------
    img: {numpy.ndarray}
        The image to draw the contour on.
    bounding_box : {tuple of int}
        The bounding_rect of the given contour.
    contour_id : {int or float}
        The corresponding ID of the given `contour`.        
    Returns
    -------
    img : {numpy.ndarray}
        The image after the `contour` and its ID is drawn on.
    ''' 
    # Center of bounding_rect.
    x, y, w, h = bounding_box
    center = ( ((x + w) // 2), ((y + h) // 2) )
    # Draw the countour number on the image
    cv2.putText(img=img,
                text=f"{contour_id}",
                org=center, # Bottom-left corner of the text string in the image.
                fontFace=cv2.FONT_HERSHEY_SIMPLEX,
                fontScale=10, 
                color=(255, 255, 255),
                thickness=40)
    return img

# %%
def XLargestBlobs(mask, top_X=None):
    
    '''
    ----------
    mask : {numpy.ndarray, dtype=np.uint8}
        The mask to get the top X largest blobs.
    top_X : {int}
        The top X contours to keep based on contour area
        ranked in decesnding order.
    Returns
    -------
    n_contours : {int}
        The number of contours found in the given `mask`.
    X_largest_blobs : {numpy.ndarray}
        The corresponding mask of the image containing only
        the top X largest contours in white.
    '''        
    # Find all contours from binarised image.
    # Note: parts of the image that you want to get should be white.
    contours, hierarchy = cv2.findContours(image=mask,
                                           mode=cv2.RETR_EXTERNAL,
                                           method=cv2.CHAIN_APPROX_NONE)   
    n_contours = len(contours)    
    # Only get largest blob if there is at least 1 contour.
    if n_contours > 0:        
        # Make sure that the number of contours to keep is at most equal 
        # to the number of contours present in the mask.
        if n_contours < top_X or top_X == None:
            top_X = n_contours        
        # Sort contours based on contour area.
        sorted_contours, bounding_boxes = SortContoursByArea(contours=contours,
                                                             reverse=True)        
        # Get the top X largest contours.
        X_largest_contours = sorted_contours[0:top_X]        
        # Create black canvas to draw contours on.
        to_draw_on = np.zeros(mask.shape, np.uint8)        
        # Draw contours in X_largest_contours.
        X_largest_blobs = cv2.drawContours(image=to_draw_on, # Draw the contours on `to_draw_on`.
                                           contours=X_largest_contours, # List of contours to draw.
                                           contourIdx=-1, # Draw all contours in `contours`.
                                           color=1, # Draw the contours in white.
                                           thickness=-1) # Thickness of the contour lines.        
    return n_contours, X_largest_blobs

# %%
def ApplyMask(img, mask):   
    '''
    ----------
    img : {numpy.ndarray}
        The image to mask.
    mask : {numpy.ndarray, dtype=np.uint8}
        The mask to apply.        
    Returns
    -------
    masked_img: {numpy.ndarray}
        The masked image.
    '''   
    masked_img = img.copy()
    masked_img[mask == 0] = 0    
    return masked_img

# %%
def HorizontalFlip(mask):    
    '''
    ----------
    mask : {numpy.ndarray, dtype=np.uint8}
        The corresponding mask of the CC image to flip.
    Returns
    -------
    horizontal_flip : {boolean}
        True means need to flip horizontally,
        False means otherwise.
    '''    
    # Get number of rows and columns in the image.
    nrows, ncols = mask.shape
    x_center = ncols // 2
    y_center = nrows // 2    
    # Sum down each column.
    col_sum = mask.sum(axis=0)
    # Sum across each row.
    row_sum = mask.sum(axis=1)    
    left_sum = sum(col_sum[0:x_center])
    right_sum = sum(col_sum[x_center:-1])
    top_sum = sum(row_sum[0:y_center])
    bottom_sum = sum(row_sum[y_center:-1])    
    if left_sum < right_sum:
        horizontal_flip = True
    else:
        horizontal_flip = False        
    return horizontal_flip

# %%
def clahe(img, clip=2.0, tile=(8, 8)):   
    '''
    ----------
    img : {numpy.ndarray}
        The image to edit.
    clip : {int or floa}
        Threshold for contrast limiting.
    tile : {tuple (int, int)}
        Size of grid for histogram equalization. Input
        image will be divided into equally sized
        rectangular tiles. `tile` defines the number of
        tiles in row and column.    
    Returns
    -------
    clahe_img : {numpy.ndarray}
        The edited image.
   '''    
    # Convert to uint8.
    # img = skimage.img_as_ubyte(img)
    img = cv2.normalize(
        img,
        None,
        alpha=0,
        beta=255,
        norm_type=cv2.NORM_MINMAX,
        dtype=cv2.CV_32F,
    )
    img_uint8 = img.astype("uint8")
    clahe_create = cv2.createCLAHE(clipLimit=clip, tileGridSize=tile)
    clahe_img = clahe_create.apply(img_uint8)
    return clahe_img

# %%
def pad(img):
    nrows, ncols, nchannels = img.shape
    # If padding is required...
    if nrows != ncols:
        # Take the longer side as the target shape.
        if ncols < nrows:
            target_shape = (nrows, nrows,nchannels)
        elif nrows < ncols:
            target_shape = (ncols, ncols,nchannels)
        # pad.
        padded_img = np.zeros(shape=target_shape)
        padded_img[:nrows, :ncols, :] = img
    # If padding is not required...
    elif nrows == ncols:
        # Return original image.
        padded_img = img
    return cv2.resize(padded_img,dim)
	
#############################################
#### Define ImageDataGenerator Functions ####
#############################################

# %%
def preprocessing_fun(img):
    #Combines all the transformations
    #img = cv2.imread(filename)
    crop_img = CropBorders(img[:,:,0])
    norm = np.zeros((crop_img.shape[0],crop_img.shape[1]))
    crop_img=cv2.normalize( crop_img,norm,alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
    # Changed bin_img to 0.25 from 0.15
    bin_img = OwnGlobalBinarise(img=crop_img,thresh=0.20, maxval=1.0)
    mask_img = OpenMask(mask=bin_img, ksize=(2, 2), operation="open")
    _, blob_img = XLargestBlobs(mask=np.array(mask_img), top_X=1)
    processed_img = ApplyMask(img=crop_img, mask=blob_img)
    horizontal_flip = HorizontalFlip(mask=blob_img)
    if horizontal_flip:
        flipped_img = np.fliplr(processed_img)
    else:
        flipped_img = processed_img
    norm = np.zeros((flipped_img.shape[0],flipped_img.shape[1]))
    norm_image = cv2.normalize(flipped_img,norm,0,255,cv2.NORM_MINMAX)
    clahe_cv = cv2.createCLAHE(clipLimit =2.0, tileGridSize=(8,8))
    norm_image=clahe_cv.apply(norm_image.astype(np.uint8))
    #norm_image=cv2.normalize(norm_image,norm,alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
    norm3=np.zeros([norm_image.shape[0],norm_image.shape[1],3])
    norm3[:,:,0]=norm_image
    norm3[:,:,1]=norm_image
    norm3[:,:,2]=norm_image
    norm3=cv2.resize(norm3,(300,600))
    return norm3

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function = preprocessing_fun
    #horizontal_flip=True,
    #vertical_flip=True,
    #rotation_range=10,
)
#'C:/Users/marcb/Downloads/miniddsm2/MINI-DDSM-Complete-JPEG-8',

'''
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.4,
    zoom_range=0.4,
    rotation_range=0.4,
    width_shift_range=0.4,
    height_shift_range=0.4,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode="nearest"
)
'''
train_generator = train_datagen.flow_from_directory(
    'C:/Datasets/Miniddsm-53gb/archive/MINI-DDSM-Complete-JPEG-8',
    target_size=(600,300), 
    interpolation="lanczos",
    color_mode='rgb', 
    batch_size=4, 
    class_mode='categorical', 
    shuffle=True)
# Out:
# Found 9170 images belonging to 3 classes.

# %%
# 'C:/Users/marcb/Downloads/miniddsm2/MINI-DDSM-Complete-JPEG-8-valid',
val_datagen = ImageDataGenerator(rescale=1. / 255) 	

valid_generator = val_datagen.flow_from_directory(
    'C:/Datasets/Miniddsm-53gb/archive/MINI-DDSM-Complete-JPEG-8-valid',
    target_size=(600,300), 
    interpolation="lanczos",
    color_mode='rgb', 
    batch_size=4, 
    class_mode='categorical', 
    shuffle=True)
	
	
###Design model
model = Sequential()
model.add(base_model)
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(16,activation='PReLU'))
model.add(BatchNormalization())
model.add(Dense(3,activation='softmax'))
model.summary()
# Out:
# Found 893 images belonging to 3 classes.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              94167659
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2048)              8192
# _________________________________________________________________
# dense_30 (Dense)             (None, 16)                32800
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16)                64
# _________________________________________________________________
# dense_31 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 94,208,766
# Trainable params: 94,045,278
# Non-trainable params: 163,488
# _________________________________________________________________

# %% [markdown]
# # Architecture

# %%
from sklearn.metrics import roc_auc_score
def auc_score(y_true, y_pred):
    if len(np.unique(y_true[:,1])) == 1:
        return 0.5
    else:
        return roc_auc_score(y_true, y_pred)
def auc(y_true, y_pred):
    return tf.numpy_function(auc_score, (y_true, y_pred), tf.double)
#in model.compile you can use auc function name

# %%
from tensorflow.keras import metrics

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-2),loss='categorical_crossentropy', 
              metrics=[
                          'categorical_accuracy'
                      ],run_eagerly=True)
model.fit(
        train_generator,
        steps_per_epoch=round(6112 /10),
        epochs=90,
        validation_data=valid_generator,
        validation_steps=round(1785 /10), workers=24)
# Out:
# Epoch 1/90
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Input In [57], in <cell line: 7>()
#       1 from tensorflow.keras import metrics
#       3 model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-2),loss='categorical_crossentropy',
#       4               metrics=[
#       5                           'categorical_accuracy'
#       6                       ],run_eagerly=True)
# ----> 7 model.fit(
#       8         train_generator,
#       9         steps_per_epoch=round(6112 /10),
#      10         epochs=90,
#      11         validation_data=valid_generator,
#      12         validation_steps=round(1785 /10), workers=24)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\engine\training.py:1184, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1177 with tf.profiler.experimental.Trace(
#    1178     'train',
#    1179     epoch_num=epoch,
#    1180     step_num=step,
#    1181     batch_size=batch_size,
#    1182     _r=1):
#    1183   callbacks.on_train_batch_begin(step)
# -> 1184   tmp_logs = self.train_function(iterator)
#    1185   if data_handler.should_sync:
#    1186     context.async_wait()
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\engine\training.py:853, in Model.make_train_function.<locals>.train_function(iterator)
#     851 def train_function(iterator):
#     852   """Runs a training execution with one step."""
# --> 853   return step_function(self, iterator)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\engine\training.py:842, in Model.make_train_function.<locals>.step_function(model, iterator)
#     839   return outputs
#     841 data = next(iterator)
# --> 842 outputs = model.distribute_strategy.run(run_step, args=(data,))
#     843 outputs = reduce_per_replica(
#     844     outputs, self.distribute_strategy, reduction='first')
#     845 write_scalar_summaries(outputs, step=model._train_counter)  # pylint: disable=protected-access
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1286, in StrategyBase.run(***failed resolving arguments***)
#    1281 with self.scope():
#    1282   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1283   # applied when the caller is also in Eager mode.
#    1284   fn = autograph.tf_convert(
#    1285       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1286   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2849, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2847   kwargs = {}
#    2848 with self._container_strategy().scope():
# -> 2849   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3632, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3630 def _call_for_each_replica(self, fn, args, kwargs):
#    3631   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3632     return fn(*args, **kwargs)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\tensorflow\python\autograph\impl\api.py:597, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     595 def wrapper(*args, **kwargs):
#     596   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 597     return func(*args, **kwargs)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\engine\training.py:835, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#     834 def run_step(data):
# --> 835   outputs = model.train_step(data)
#     836   # Ensure counter is updated only if `train_step` succeeds.
#     837   with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\engine\training.py:787, in Model.train_step(self, data)
#     785 # Run forward pass.
#     786 with tf.GradientTape() as tape:
# --> 787   y_pred = self(x, training=True)
#     788   loss = self.compiled_loss(
#     789       y, y_pred, sample_weight, regularization_losses=self.losses)
#     790 # Run backwards pass.
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\engine\base_layer.py:1037, in Layer.__call__(self, *args, **kwargs)
#    1033   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1035 with autocast_variable.enable_auto_cast_variables(
#    1036     self._compute_dtype_object):
# -> 1037   outputs = call_fn(inputs, *args, **kwargs)
#    1039 if self._activity_regularizer:
#    1040   self._handle_activity_regularization(inputs, outputs)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\engine\sequential.py:369, in Sequential.call(self, inputs, training, mask)
#     367   if not self.built:
#     368     self._init_graph_network(self.inputs, self.outputs)
# --> 369   return super(Sequential, self).call(inputs, training=training, mask=mask)
#     371 outputs = inputs  # handle the corner case where self.layers is empty
#     372 for layer in self.layers:
#     373   # During each iteration, `inputs` are the inputs to `layer`, and `outputs`
#     374   # are the outputs of `layer` applied to `inputs`. At the end of each
#     375   # iteration `inputs` is set to `outputs` to prepare for the next layer.
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\engine\functional.py:414, in Functional.call(self, inputs, training, mask)
#     395 @doc_controls.do_not_doc_inheritable
#     396 def call(self, inputs, training=None, mask=None):
#     397   """Calls the model on new inputs.
#     398
#     399   In this case `call` just reapplies
#    (...)
#     412       a list of tensors if there are more than one outputs.
#     413   """
# --> 414   return self._run_internal_graph(
#     415       inputs, training=training, mask=mask)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\engine\functional.py:550, in Functional._run_internal_graph(self, inputs, training, mask)
#     547   continue  # Node is not computable, try skipping.
#     549 args, kwargs = node.map_arguments(tensor_dict)
# --> 550 outputs = node.layer(*args, **kwargs)
#     552 # Update tensor_dict.
#     553 for x_id, y in zip(node.flat_output_ids, tf.nest.flatten(outputs)):
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\engine\base_layer.py:1037, in Layer.__call__(self, *args, **kwargs)
#    1033   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1035 with autocast_variable.enable_auto_cast_variables(
#    1036     self._compute_dtype_object):
# -> 1037   outputs = call_fn(inputs, *args, **kwargs)
#    1039 if self._activity_regularizer:
#    1040   self._handle_activity_regularization(inputs, outputs)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\engine\functional.py:414, in Functional.call(self, inputs, training, mask)
#     395 @doc_controls.do_not_doc_inheritable
#     396 def call(self, inputs, training=None, mask=None):
#     397   """Calls the model on new inputs.
#     398
#     399   In this case `call` just reapplies
#    (...)
#     412       a list of tensors if there are more than one outputs.
#     413   """
# --> 414   return self._run_internal_graph(
#     415       inputs, training=training, mask=mask)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\engine\functional.py:550, in Functional._run_internal_graph(self, inputs, training, mask)
#     547   continue  # Node is not computable, try skipping.
#     549 args, kwargs = node.map_arguments(tensor_dict)
# --> 550 outputs = node.layer(*args, **kwargs)
#     552 # Update tensor_dict.
#     553 for x_id, y in zip(node.flat_output_ids, tf.nest.flatten(outputs)):
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\engine\base_layer.py:1037, in Layer.__call__(self, *args, **kwargs)
#    1033   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1035 with autocast_variable.enable_auto_cast_variables(
#    1036     self._compute_dtype_object):
# -> 1037   outputs = call_fn(inputs, *args, **kwargs)
#    1039 if self._activity_regularizer:
#    1040   self._handle_activity_regularization(inputs, outputs)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\layers\core.py:1544, in SlicingOpLambda.__init__.<locals>._call_wrapper(*args, **kwargs)
#    1541     value = new_value
#    1542   new_kwargs[key] = value
# -> 1544 return original_call(*new_args, **new_kwargs)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\layers\core.py:1350, in TFOpLambda.__init__.<locals>._call_wrapper(*args, **kwargs)
#    1349 def _call_wrapper(*args, **kwargs):
# -> 1350   return self._call_wrapper(*args, **kwargs)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\keras\layers\core.py:1382, in TFOpLambda._call_wrapper(self, *args, **kwargs)
#    1375 with tf.GradientTape(watch_accessed_variables=True) as tape, \
#    1376     tf.variable_creator_scope(_variable_creator):
#    1377   # We explicitly drop `name` arguments here,
#    1378   # to guard against the case where an op explicitly has a
#    1379   # `name` passed (which is susceptible to producing
#    1380   # multiple ops w/ the same name when the layer is reused)
#    1381   kwargs.pop('name', None)
# -> 1382   result = self.function(*args, **kwargs)
#    1383 self._check_variables(created_variables, tape.watched_variables())
#    1384 return result
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\tensorflow\python\util\dispatch.py:206, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     204 """Call target, and fall back on dispatchers if there is a TypeError."""
#     205 try:
# --> 206   return target(*args, **kwargs)
#     207 except (TypeError, ValueError):
#     208   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     209   # TypeError, when given unexpected types.  So we need to catch both.
#     210   result = dispatch(wrapper, args, kwargs)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\tensorflow\python\ops\array_ops.py:1041, in _slice_helper(tensor, slice_spec, var)
#    1039   var_empty = constant([], dtype=dtypes.int32)
#    1040   packed_begin = packed_end = packed_strides = var_empty
# -> 1041 return strided_slice(
#    1042     tensor,
#    1043     packed_begin,
#    1044     packed_end,
#    1045     packed_strides,
#    1046     begin_mask=begin_mask,
#    1047     end_mask=end_mask,
#    1048     shrink_axis_mask=shrink_axis_mask,
#    1049     new_axis_mask=new_axis_mask,
#    1050     ellipsis_mask=ellipsis_mask,
#    1051     var=var,
#    1052     name=name)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\tensorflow\python\util\dispatch.py:206, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     204 """Call target, and fall back on dispatchers if there is a TypeError."""
#     205 try:
# --> 206   return target(*args, **kwargs)
#     207 except (TypeError, ValueError):
#     208   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     209   # TypeError, when given unexpected types.  So we need to catch both.
#     210   result = dispatch(wrapper, args, kwargs)
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\tensorflow\python\ops\array_ops.py:1214, in strided_slice(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#    1211 if strides is None:
#    1212   strides = ones_like(begin)
# -> 1214 op = gen_array_ops.strided_slice(
#    1215     input=input_,
#    1216     begin=begin,
#    1217     end=end,
#    1218     strides=strides,
#    1219     name=name,
#    1220     begin_mask=begin_mask,
#    1221     end_mask=end_mask,
#    1222     ellipsis_mask=ellipsis_mask,
#    1223     new_axis_mask=new_axis_mask,
#    1224     shrink_axis_mask=shrink_axis_mask)
#    1226 parent_name = name
#    1228 if var is not None:
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:10510, in strided_slice(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#   10508   return _result
#   10509 except _core._NotOkStatusException as e:
# > 10510   _ops.raise_from_not_ok_status(e, name)
#   10511 except _core._FallbackException:
#   10512   pass
#
# File ~\anaconda3\envs\Tensorflow-GPU\lib\site-packages\tensorflow\python\framework\ops.py:6941, in raise_from_not_ok_status(e, name)
#    6939 message = e.message + (" name: " + name if name is not None else "")
#    6940 # pylint: disable=protected-access
# -> 6941 six.raise_from(core._status_to_exception(e.code, message), None)
#
# File <string>:3, in raise_from(value, from_value)
#
# InvalidArgumentError: Index out of range using input dim 4; input has only 4 dims [Op:StridedSlice] name: sequential_1/resnet50/tf.__operators__.getitem_6/strided_slice/

# %%
test_datagen = ImageDataGenerator(
    rescale=1./255
)

test_generator = test_datagen.flow_from_directory(
    'C:/Datasets/Miniddsm-53gb/archive/MINI-DDSM-Complete-JPEG-8-test',
    target_size=(600,300), 
    interpolation="lanczos",
    color_mode='rgb', 
    batch_size=4, 
    class_mode='categorical', 
    shuffle=True)

#y_pred=model.predict_on_batch(test_datagen)
test_evaluation = model.evaluate(test_generator,verbose = 0)
# Out:
# Found 921 images belonging to 3 classes.

# %%
for i in range(0,len(model.metrics_names)):
    print("%s%s: %.2f%%" % (" ",model.metrics_names[i], test_evaluation[i]*100))


#print("Final Model Accuracy = ", (test_acc))
#print('Accuracy:', test_evaluation.accuracy_score())
#print('Precision:', test_evaluation.precision_score())
#print('Recall:', np.round(metrics.recall_score(y_test[:,0],y_pred, average='weighted'),5))
#print('F1 Score:', np.round(metrics.f1_score(y_test[:,0], y_pred, average='weighted'),5))
#print('ROC AUC Score:', np.round(metrics.roc_auc_score(y_test[:,0], y_pred,multi_class='ovo', average='weighted'),5))
#print('Cohen Kappa Score:', np.round(metrics.cohen_kappa_score(y_test[:,0], y_pred),5))
#print('\t\tClassification Report:\n', metrics.classification_report(y_test[:,0], y_pred,target_names=target))
# Out:
#  loss: 93.12%
#  categorical_accuracy: 51.57%
